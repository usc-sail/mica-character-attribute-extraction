# %%
import os
import collections
import pandas as pd

# %%
attr_type_file = "/data/sbaruah/narrative_understanding/chatter/attr_types/character_attribute_types.csv"
attr_df = pd.read_csv(attr_type_file, index_col=None)
print(attr_df.shape)
display(attr_df.head(5))
# Out:
# (367, 3)
#                                          Description       Character  \
# 0  The southeast corner of the intersection of Br...    Sidney Falco
# 1  DOYLE STANDISH is cleaning his computer with a...  Doyle Standish
# 2  The driver brakes, swerves and comes to a halt...    Tamara Drewe
# 3  125 RING, OLYMPIA GRAND HALL - 9:20 PM 125 TIT...      Micky Ward
# 4  Rolling to a stop half-way up the block ... Ja...    Eddie Bunker
#
#               Attribute Types
# 0     Age, Appearance, Attire
# 1  Age, Attitude, Possessions
# 2    Age, Appearance, Emotion
# 3      Performance, Qualities
# 4        Possession, Movement

# %%
attr_types = [attr.strip() for attr_list in attr_df["Attribute Types"].dropna().str.split(",") for attr in attr_list]
print(f"{len(attr_types)}")
# Out:
# 867

# %%
collections.Counter(attr_types)
# Out:
# Counter({'Age': 162,
#          'Appearance': 112,
#          'Possession': 102,
#          'Attire': 68,
#          'Profession': 51,
#          'Emotion': 48,
#          'Qualities': 30,
#          'Attitude': 18,
#          'Posture': 15,
#          'Possessions': 14,
#          'Accomplishment': 13,
#          'Action': 11,
#          'Hair Type': 10,
#          'Health Status': 10,
#          'Ethnicity': 7,
#          'Social Status': 7,
#          'Personality': 6,
#          'Occupation': 5,
#          'Habits': 5,
#          'Activity': 5,
#          'Wealth': 4,
#          'Demeanor': 4,
#          'Hair Color': 4,
#          'Relationship': 3,
#          'Skill': 3,
#          'Characteristics': 3,
#          'Behavior': 3,
#          'Status': 3,
#          'Surroundings': 3,
#          'Race': 3,
#          'Nationality': 3,
#          'Perception': 3,
#          'Reaction': 3,
#          'Voice': 3,
#          'Movement': 2,
#          'Expression': 2,
# ...
